# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Airplane_Crashes_and_Fatalities_Since_1908.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         5268 non-null   int64
#  1   Date          5268 non-null   object
#  2   Time          3049 non-null   object
#  3   Location      5248 non-null   object
#  4   Operator      5250 non-null   object
#  5   Flight #      1069 non-null   object
#  6   Route         3562 non-null   object
#  7   Type          5241 non-null   object
#  8   Registration  4933 non-null   object
#  9   cn/In         4040 non-null   object
#  10  Aboard        5246 non-null   float64
#  11  Fatalities    5256 non-null   float64
#  12  Ground        5246 non-null   float64
#  13  Summary       4878 non-null   object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 576.3+ KB

# %%
df.tail(5)
# Out:
#       index        Date   Time  \
# 5263   5263  05/20/2009  06:30
# 5264   5264  05/26/2009    NaN
# 5265   5265  06/01/2009  00:15
# 5266   5266  06/07/2009  08:30
# 5267   5267  06/08/2009    NaN
#
#                                                Location  \
# 5263                             Near Madiun, Indonesia
# 5264                  Near Isiro, DemocratiRepubliCongo
# 5265  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266       Near Port Hope Simpson, Newfoundland, Canada
# 5267                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 5263                           Jakarta - Maduin
# ...

# %%
df.isnull().sum()
# Out:
# index              0
# Location          20
# Operator          18
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# Date               0
# dtype: int64

# %%
df.describe()
# Out:
#             index       Aboard   Fatalities       Ground
# count  5268.00000  5246.000000  5256.000000  5246.000000
# mean   2633.50000    27.554518    20.068303     1.608845
# std    1520.88494    43.076711    33.199952    53.987827
# min       0.00000     0.000000     0.000000     0.000000
# 25%    1316.75000     5.000000     3.000000     0.000000
# 50%    2633.50000    13.000000     9.000000     0.000000
# 75%    3950.25000    30.000000    23.000000     0.000000
# max    5267.00000   644.000000   583.000000  2750.000000

# %%
df.isnull().sum()
# Out:
# index             0
# Location         20
# Operator         18
# Type             27
# Registration    335
# Aboard           22
# Fatalities       12
# Ground           22
# Summary         390
# Date              0
# dtype: int64

# %%
df
# Out:
#       index                                           Location  \
# 0         0                                Fort Myer, Virginia
# 1         1                            AtlantiCity, New Jersey
# 2         2                 Victoria, British Columbia, Canada
# 3         3                                 Over the North Sea
# 4         4                         Near Johannisthal, Germany
# ...     ...                                                ...
# 5263   5263                             Near Madiun, Indonesia
# 5264   5264                  Near Isiro, DemocratiRepubliCongo
# 5265   5265  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266   5266       Near Port Hope Simpson, Newfoundland, Canada
# 5267   5267                  State of Arunachal Pradesh, India
#
#                              Operator                              Type  \
# 0                Military - U.S. Army                  Wright Flyer III
# ...

# %%
A = np.array([[1, -2, 4],
             [2, 0, -1]])
B = np.array([[5, 2, 3],
             [4, 6, 2]])

# %%
task1 = A + B

# %%
A1 = np.array([[1, 2],
             [2, -1],
              [3, 0]])
B1 = np.array([[-1, 1],
             [1, 2],
              [0, 0]])

# %%
C = A1 - 3*B1
task2 = C

# %%
A2 = np.array([[1, -1],
             [2, 0],
              [3, 0]])
B2 = np.array([[1, 1],
             [2, 0]])
C2 = np.dot(A2, B2)
task3 = C2

# %%
A3 = np.array([[6,-1,4],
              [2, 1, 10],
              [8, 0, 2]])
task4 = np.linalg.det(A3)

# %%
A4 = np.array([[3, 3, -1],
              [4, 1, 3],
              [1, -2, -2]])
task5 = np.linalg.inv(A4)
task6 = np.linalg.inv(task5)
task5
task6
# Out:
# array([[ 3.,  3., -1.],
#        [ 4.,  1.,  3.],
#        [ 1., -2., -2.]])
